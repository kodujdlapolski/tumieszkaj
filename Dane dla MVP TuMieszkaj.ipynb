# %% [markdown]
# # Cel
#
# Celem tego dokumentu jest sprawdzenie danych do MVP dla gminy Imielin. W szczególności:
# - dostępności danych dla różnych lat
# - jakości danych

# %%
import pandas as pd

# %% [markdown]
# ## Rodzaj zabudowy

# %% [markdown]
# ## Rozwój zabudowy w ostatnich latach

# %% [markdown]
# ## Ilość terenów zielonych

# %%
df = pd.read_csv('data/Imielin TERENY ZIELENI.csv')
df
# Out:
#      Rok  TERENY ZIELENI/Rodzinne ogrody działkowe/ogrody liczba  \
# 0   1996                                                0.4
# 1   1997                                                0.4
# 2   1998                                                0.4
# 3   1999                                                0.4
# 4   2000                                                0.4
# 5   2001                                                0.4
# 6   2002                                                0.4
# 7   2003                                                0.4
# 8   2004                                                NaN
# 9   2005                                                NaN
# 10  2006                                                NaN
# 11  2007                                                NaN
# 12  2008                                                NaN
# 13  2009                                                NaN
# 14  2010                                                NaN
# ...

# %% [markdown]
# Dla porównania wrzucam podobne dane z Kielc.

# %%
df = pd.read_csv('data/Kielce TERENY ZIELENI.csv', index_col='Rok')
df
# Out:
#       TERENY ZIELENI/Rodzinne ogrody działkowe/ogrody liczba  \
# Rok
# 2004                                              62.40
# 2005                                              62.40
# 2006                                              62.40
# 2007                                              62.40
# 2008                                              62.40
# 2009                                              62.40
# 2010                                              62.40
# 2011                                              62.40
# 2012                                              67.30
# 2013                                              72.95
# 2014                                              72.95
# 2015                                              72.95
# 2016                                              72.85
# 2017                                              71.00
# 2018                                              69.14
#
# ...

# %% [markdown]
# ## Sport i rekreacja

# %%
df = pd.read_csv('data/Imielin ŚCIEŻKI ROWEROWE.csv')
df
# Out:
#     Rok  \
# 0  2012
# 1  2013
# 2  2014
# 3  2015
# 4  2016
# 5  2017
# 6  2018
#
#    ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe (drogi dla rowerów) ogółem  \
# 0                                                2.4
# 1                                                1.3
# 2                                                1.3
# 3                                                3.7
# 4                                                3.7
# 5                                                3.7
# 6                                                5.3
#
#    ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe na 10 tys. km2  \
# 0                                              857.4
# 1                                              464.5
# 2                                              464.5
# 3                                             1321.9
# 4                                             1321.9
# ...

# %%
df[['ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe na 10 tys. km2', 
    'ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe na 10 tys. ludności']]
# Out:
#    ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe na 10 tys. km2  \
# 0                                              857.4
# 1                                              464.5
# 2                                              464.5
# 3                                             1321.9
# 4                                             1321.9
# 5                                             1321.9
# 6                                             1893.5
#
#    ŚCIEŻKI ROWEROWE/Długość ścieżek rowerowych (dróg dla rowerów)/ścieżki rowerowe na 10 tys. ludności
# 0                                               2.81
# 1                                               1.51
# 2                                               1.49
# 3                                               4.18
# 4                                               4.16
# 5                                               4.09
# 6                                               5.79

# %%
df = pd.read_csv('data/Imielin SPORT.csv')
df
# Out:
#     Rok  \
# 0  2010
# 1  2012
# 2  2014
# 3  2016
# 4  2018
#
#    SPORT/Kluby sportowe łącznie z klubami wyznaniowymi i UKS/ćwiczący ogółem  \
# 0                                               19.0
# 1                                              130.0
# 2                                               24.0
# 3                                              207.0
# 4                                              329.0
#
#    SPORT/Kluby sportowe łącznie z klubami wyznaniowymi i UKS/ćwiczący kobiety  \
# 0                                                7.0
# 1                                               14.0
# 2                                                8.0
# 3                                              152.0
# 4                                              103.0
#
#    SPORT/Kluby sportowe łącznie z klubami wyznaniowymi i UKS/trenerzy  \
# 0                                                1.0
# 1                                                5.0
# ...

# %% [markdown]
# ## Infrastruktura drogowa

# %% [markdown]
# ## Łatwość dojazdu do/z wybranego miejsca

# %% [markdown]
# ## Usługi

# %% [markdown]
# ## Środowisko

# %% [markdown]
# ## Zasięg

# %% [markdown]
# ## Edukacja

# %% [markdown]
# ## Rozwój gminy

# %% [markdown]
# ## Nieruchomości
